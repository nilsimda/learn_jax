# %%
import jax
import flax
import optax
import numpy as np
import gymnasium as gym
from matplotlib import animation
import matplotlib.pyplot as plt
from jax import random, numpy as jnp

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('animation', html='jshtml')

# %%
env = gym.make("CartPole-v1", render_mode="rgb_array")
obs, info = env.reset(seed=42)
obs, info
# Out:
# (array([ 0.0273956 , -0.00611216,  0.03585979,  0.0197368 ], dtype=float32),
#  {})

# %%
def show_env(env):
    img = env.render()
    plt.figure(figsize=(4,4))
    plt.imshow(img)
    plt.axis('off')

show_env(env)

# %%
action=1
obs,reward,done,truncated,info = env.step(action)
obs, reward, done, truncated
# Out:
# (array([ 0.02727336,  0.18847767,  0.03625453, -0.26141977], dtype=float32),
#  1.0,
#  False,
#  False)

# %%
def basic_policy(obs):
    angle = obs[2]
    return 0 if angle < 0 else 1

totals = []
for episode in range(500):
    episode_rewards = 0
    obs, info = env.reset(seed=episode)
    for step in range(200):
        action = basic_policy(obs)
        obs, reward, done, truncated, info = env.step(action)
        episode_rewards += reward
        if done or truncated:
            break
    totals.append(episode_rewards)

# %%
def update_scene(num, frames, patch):
    patch.set_data(frames[num])
    return patch,

def plot_animation(frames, repeat=False, interval=40):
    fig = plt.figure()
    patch = plt.imshow(frames[0])
    plt.axis('off')
    anim = animation.FuncAnimation(
        fig, update_scene, fargs=(frames, patch),
        frames=len(frames), repeat=repeat, interval=interval)
    plt.close()
    return anim

def show_one_episode(policy, n_max_steps=200, seed=42):
    frames = []
    env = gym.make("CartPole-v1", render_mode="rgb_array")
    np.random.seed(seed)
    obs, info = env.reset(seed=seed)
    for step in range(n_max_steps):
        frames.append(env.render())
        action = policy(obs)
        obs, reward, done, truncated, info = env.step(action)
        if done or truncated:
            break
    env.close()
    return plot_animation(frames)

show_one_episode(basic_policy)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img7ffba7abf87547d78b5ddfeb63fd91b2">
#   <div class="anim-controls">
#     <input id="_anim_slider7ffba7abf87547d78b5ddfeb63fd91b2" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim7ffba7abf87547d78b5ddfeb63fd91b2.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim7ffba7abf87547d78b5ddfeb63fd91b2.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select7ffba7abf87547d78b5ddfeb63fd91b2"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_7ffba7abf87547d78b5ddfeb63fd91b2"
#              checked>
#       <label for="_anim_radio1_7ffba7abf87547d78b5ddfeb63fd91b2">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_7ffba7abf87547d78b5ddfeb63fd91b2"
#              >
#       <label for="_anim_radio2_7ffba7abf87547d78b5ddfeb63fd91b2">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_7ffba7abf87547d78b5ddfeb63fd91b2"
#              >
#       <label for="_anim_radio3_7ffba7abf87547d78b5ddfeb63fd91b2">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img7ffba7abf87547d78b5ddfeb63fd91b2";
#     var slider_id = "_anim_slider7ffba7abf87547d78b5ddfeb63fd91b2";
#     var loop_select_id = "_anim_loop_select7ffba7abf87547d78b5ddfeb63fd91b2";
#     var frames = new Array(55);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAANyklEQ

# %%
import numpy as np

np.mean(totals), np.std(totals), min(totals), max(totals)
# Out:
# (41.698, 8.389445512070509, 24.0, 63.0)

# %%
from flax import linen as nn
from jax import random, numpy as jnp

class MLP(nn.Module):
    @nn.compact
    def __call__(self, x):
        x = nn.Dense(5)(x)
        x = nn.relu(x)
        x = nn.Dense(1)(x)
        return x

key, subkey = random.split(random.PRNGKey(0))
model = MLP()
params = model.init(subkey, obs[np.newaxis, :])
y = model.apply(params, obs[np.newaxis, :])

print('Initialized parameter shapes:\n', jax.tree_map(jnp.shape, params))
print('Output:\n', y)
# Out:
# Initialized parameter shapes:
#  {'params': {'Dense_0': {'bias': (5,), 'kernel': (4, 5)}, 'Dense_1': {'bias': (1,), 'kernel': (5, 1)}}}
# Output:
#  [[0.04724307]]

# %%
@jax.jit
def loss_fn(params, obs, key):
    logits = model.apply(params, obs[np.newaxis])
    left_proba = nn.sigmoid(logits)
    action = random.uniform(key, (1,1)) > left_proba
    labels = jnp.array([[1.]]) - action
    return optax.sigmoid_binary_cross_entropy(logits, labels).mean(), action

def play_one_step(params, model, env, obs, key):
    grads, action = jax.grad(loss_fn, has_aux=True)(params, obs, key)
    obs, reward, done, truncated, _ = env.step(action.item())
    return obs, reward, done, truncated, grads

# %%
play_one_step(params, model, env, obs, key)
# Out:
# (array([ 0.13841096,  0.5369683 , -0.04535787, -0.6319416 ], dtype=float32),
#  1.0,
#  False,
#  False,
#  {'params': {'Dense_0': {'bias': Array([ 0.        ,  0.        , -0.29707745,  0.18983565,  0.        ],      dtype=float32),
#     'kernel': Array([[ 0.        ,  0.        , -0.05615344,  0.03588264,  0.        ],
#            [ 0.        ,  0.        , -0.11421002,  0.07298142,  0.        ],
#            [-0.        , -0.        ,  0.06584532, -0.04207586, -0.        ],
#            [-0.        , -0.        ,  0.15316193, -0.09787211, -0.        ]],      dtype=float32)},
#    'Dense_1': {'bias': Array([0.528579], dtype=float32),
#     'kernel': Array([[0.        ],
#            [0.        ],
#            [0.09426378],
#            [0.31671634],
#            [0.        ]], dtype=float32)}}})

# %%
def play_multiple_episodes(env, n_episodes, n_max_steps, model, params, key):
    all_rewards = []
    all_grads = []
    for _ in range(n_episodes):
        current_rewards = []
        current_grads = []
        obs, _ = env.reset()
        for _ in range(n_max_steps):
            key, subkey = random.split(key)
            obs, reward, done, truncated, grads = play_one_step(
                params, model, env, obs, subkey
            )
            current_rewards.append(reward)
            current_grads.append(grads)
            if done or truncated: break
        all_rewards.append(current_rewards)
        all_grads.append(current_grads)
    return all_rewards, all_grads

# %%
def discount_rewards(rewards, discount_factor):
    discounted = np.array(rewards)
    for step in range(len(rewards)-2, -1, -1):
        discounted[step] += discounted[step + 1]* discount_factor
    return discounted

def discount_and_normalize_rewards(all_rewards, discount_factor):
    all_discounted_rewards = [discount_rewards(rewards, discount_factor)
                              for rewards in all_rewards]
    flat_rewards = np.concatenate(all_discounted_rewards)
    mean, std = flat_rewards.mean(), flat_rewards.std()
    return [(discounted_rewards-mean)/std 
            for discounted_rewards in all_discounted_rewards]

# %%
opt = optax.nadam(learning_rate=0.01)
opt_state = opt.init(params)
n_iterations = 150
n_episodes_per_update = 10
n_max_steps = 200
discount_factor = 0.95

# %%
for it in range(n_iterations):
    all_rewards, all_grads = play_multiple_episodes(
        env, n_episodes_per_update, n_max_steps, model, params, key
    )

    total_rewards = sum(map(sum, all_rewards))
    print(f"\rIteration: {it + 1}/{n_iterations},"
          f" mean rewards: {total_rewards / n_episodes_per_update:.1f}", end="")

    all_final_rewards = discount_and_normalize_rewards(all_rewards, discount_factor)
    all_mean_grads = []
    params_arr, params_info = jax.tree_util.tree_flatten(params)
    for var_index in range(len(params_arr)):
        scaled_grads = jnp.array([reward * jax.tree_util.tree_leaves(all_grads[episode][step])[var_index]
                  for episode, rewards in enumerate(all_final_rewards)
                  for step, reward in enumerate(rewards)])
        mean_grads = jnp.mean(scaled_grads, axis=0)
        all_mean_grads.append(mean_grads)
    
    grads = jax.tree_util.tree_unflatten(params_info, all_mean_grads)
    #print(grads)
    updates, opt_state = opt.update(grads, opt_state, params)
    params = optax.apply_updates(params, updates)
# Out:
# Iteration: 3/150, mean rewards: 21.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 2
#       1 for it in range(n_iterations):
# ----> 2     all_rewards, all_grads = play_multiple_episodes(
#       3         env, n_episodes_per_update, n_max_steps, model, params, key
#       4     )
#       6     total_rewards = sum(map(sum, all_rewards))
#       7     print(f"\rIteration: {it + 1}/{n_iterations},"
#       8           f" mean rewards: {total_rewards / n_episodes_per_update:.1f}", end="")
#
# Cell In[55], line 10, in play_multiple_episodes(env, n_episodes, n_max_steps, model, params, key)
#       8 for _ in range(n_max_steps):
#       9     key, subkey = random.split(key)
# ---> 10     obs, reward, done, truncated, grads = play_one_step(
#      11         params, model, env, obs, subkey
#      12     )
#      13     current_rewards.append(reward)
#      14     current_grads.append(grads)
#
# Cell In[53], line 10, in play_one_step(params, model, env, obs, key)
#       9 def play_one_step(params, model, env, obs, key):
# ---> 10     grads, action = jax.jit(jax.grad(loss_fn, has_aux=True))(params, obs, key)
#      11     obs, reward, done, truncated, _ = env.step(action.item())
#      12     return obs, reward, done, truncated, grads
#
#     [... skipping hidden 1 frame]
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/pjit.py:257, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 @api_boundary
#     256 def cache_miss(*args, **kwargs):
# --> 257   outs, out_flat, out_tree, args_flat, jaxpr = _python_pjit_helper(
#     258       fun, infer_params_fn, *args, **kwargs)
#     259   executable = _read_most_recent_pjit_call_executable(jaxpr)
#     260   fastpath_data = _get_fastpath_data(executable, out_tree, args_flat, out_flat)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/pjit.py:168, in _python_pjit_helper(fun, infer_params_fn, *args, **kwargs)
#     166   dispatch.check_arg(arg)
#     167 try:
# --> 168   out_flat = pjit_p.bind(*args_flat, **params)
#     169 except pxla.DeviceAssignmentMismatchError as e:
#     170   fails, = e.args
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/core.py:2740, in AxisPrimitive.bind(self, *args, **params)
#    2736 axis_main = max((axis_frame(a).main_trace for a in used_axis_names(self, params)),
#    2737                 default=None, key=lambda t: getattr(t, 'level', -1))
#    2738 top_trace = (top_trace if not axis_main or axis_main.level < top_trace.level
#    2739              else axis_main.with_cur_sublevel())
# -> 2740 return self.bind_with_trace(top_trace, args, params)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/core.py:447, in Primitive.bind_with_trace(self, trace, args, params)
#     446 def bind_with_trace(self, trace, args, params):
# --> 447   out = trace.process_primitive(self, map(trace.full_raise, args), params)
#     448   return map(full_lower, out) if self.multiple_results else full_lower(out)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/core.py:935, in EvalTrace.process_primitive(self, primitive, tracers, params)
#     934 def process_primitive(self, primitive, tracers, params):
# --> 935   return primitive.impl(*tracers, **params)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/pjit.py:1245, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1242 donated_argnums = [i for i, d in enumerate(donated_invars) if d]
#    1243 has_explicit_sharding = _pjit_explicit_sharding(
#    1244     in_shardings, out_shardings, None, None)
# -> 1245 return xc._xla.pjit(name, f, call_impl_cache_miss, [], [], donated_argnums,
#    1246                     tree_util.dispatch_registry,
#    1247                     _get_cpp_global_cache(has_explicit_sharding))(*args)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/pjit.py:1229, in _pjit_call_impl.<locals>.call_impl_cache_miss(*args_, **kwargs_)
#    1228 def call_impl_cache_miss(*args_, **kwargs_):
# -> 1229   out_flat, compiled = _pjit_call_impl_python(
#    1230       *args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1231       out_shardings=out_shardings, resource_env=resource_env,
#    1232       donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1233       inline=inline)
#    1234   fastpath_data = _get_fastpath_data(
#    1235       compiled, tree_structure(out_flat), args, out_flat)
#    1236   return out_flat, fastpath_data
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/pjit.py:1165, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, resource_env, donated_invars, name, keep_unused, inline, *args)
#    1156 global _most_recent_pjit_call_executable
#    1158 in_shardings = _resolve_in_shardings(
#    1159     args, in_shardings, out_shardings,
#    1160     resource_env.physical_mesh if resource_env is not None else None)
#    1162 compiled = _pjit_lower(
#    1163     jaxpr, in_shardings, out_shardings, resource_env,
#    1164     donated_invars, name, keep_unused, inline,
# -> 1165     lowering_parameters=mlir.LoweringParameters()).compile()
#    1166 _most_recent_pjit_call_executable.weak_key_dict[jaxpr] = compiled
#    1167 # This check is expensive so only do it if enable_checks is on.
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2219, in MeshComputation.compile(self, compiler_options)
#    2217 def compile(self, compiler_options=None) -> MeshExecutable:
#    2218   if self._executable is None or compiler_options is not None:
# -> 2219     executable = UnloadedMeshExecutable.from_hlo(
#    2220         self._name, self._hlo, **self.compile_args,
#    2221         compiler_options=compiler_options)
#    2222     if compiler_options is None:
#    2223       self._executable = executable
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2659, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2656       mesh = i.mesh  # type: ignore
#    2657       break
# -> 2659 xla_executable, compile_options = _cached_compilation(
#    2660     hlo, name, mesh, spmd_lowering,
#    2661     tuple_args, auto_spmd_lowering, allow_prop_to_outputs,
#    2662     tuple(host_callbacks), backend, da, pmap_nreps,
#    2663     compiler_options_keys, compiler_options_values)
#    2665 if hasattr(backend, "compile_replicated"):
#    2666   semantics_in_shardings = SemanticallyEqualShardings(in_shardings)  # type: ignore
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/interpreters/pxla.py:2528, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, _allow_propagation_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_keys, compiler_options_values)
#    2523   return None, compile_options
#    2525 with dispatch.log_elapsed_time(
#    2526     "Finished XLA compilation of {fun_name} in {elapsed_time} sec",
#    2527     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2528   xla_executable = compiler.compile_or_get_cached(
#    2529       backend, computation, dev, compile_options, host_callbacks)
#    2530 return xla_executable, compile_options
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/compiler.py:333, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks)
#     331 else:
#     332   start_time = time.monotonic()
# --> 333   executable = backend_compile(backend, computation,
#     334                               compile_options, host_callbacks)
#     335   compile_time = time.monotonic() - start_time
#     336   _cache_write(cache_key, compile_time, module_name, backend, executable,
#     337                host_callbacks)
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/profiler.py:336, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     333 @wraps(func)
#     334 def wrapper(*args, **kwargs):
#     335   with TraceAnnotation(name, **decorator_kwargs):
# --> 336     return func(*args, **kwargs)
#     337   return wrapper
#
# File ~/miniconda3/envs/jax/lib/python3.11/site-packages/jax/_src/compiler.py:256, in backend_compile(backend, module, options, host_callbacks)
#     251   return backend.compile(built_c, compile_options=options,
#     252                          host_callbacks=host_callbacks)
#     253 # Some backends don't have `host_callbacks` option yet
#     254 # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     255 # to take in `host_callbacks`
# --> 256 return backend.compile(built_c, compile_options=options)
#
# KeyboardInterrupt:

# %%
def pg_policy(obs):
    left_proba = model.apply(params, obs[np.newaxis, :])
    return (np.random.rand() > left_proba).item()

show_one_episode(pg_policy)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgc6e3153eb859413396bc02fc855ad77c">
#   <div class="anim-controls">
#     <input id="_anim_sliderc6e3153eb859413396bc02fc855ad77c" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animc6e3153eb859413396bc02fc855ad77c.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animc6e3153eb859413396bc02fc855ad77c.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animc6e3153eb859413396bc02fc855ad77c.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animc6e3153eb859413396bc02fc855ad77c.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animc6e3153eb859413396bc02fc855ad77c.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animc6e3153eb859413396bc02fc855ad77c.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animc6e3153eb859413396bc02fc855ad77c.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animc6e3153eb859413396bc02fc855ad77c.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animc6e3153eb859413396bc02fc855ad77c.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animc6e3153eb859413396bc02fc855ad77c.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectc6e3153eb859413396bc02fc855ad77c"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_c6e3153eb859413396bc02fc855ad77c"
#              checked>
#       <label for="_anim_radio1_c6e3153eb859413396bc02fc855ad77c">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_c6e3153eb859413396bc02fc855ad77c"
#              >
#       <label for="_anim_radio2_c6e3153eb859413396bc02fc855ad77c">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_c6e3153eb859413396bc02fc855ad77c"
#              >
#       <label for="_anim_radio3_c6e3153eb859413396bc02fc855ad77c">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgc6e3153eb859413396bc02fc855ad77c";
#     var slider_id = "_anim_sliderc6e3153eb859413396bc02fc855ad77c";
#     var loop_select_id = "_anim_loop_selectc6e3153eb859413396bc02fc855ad77c";
#     var frames = new Array(158);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjguMiwgaHR0cHM6Ly9tYXRwbG90bGliLm9yZy8g+/7EAAAACXBIWXMAAA9h\
# AAAPYQGoP6dpAAANyklE

# %%
rewards, _  = play_multiple_episodes(env, 5, 200, model, params, key)

[sum(r) for r in rewards]
# Out:
# [200.0, 200.0, 200.0, 200.0, 145.0]
